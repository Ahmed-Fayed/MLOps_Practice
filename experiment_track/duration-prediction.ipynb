# %%
# !python -V
# Out:
# Python 3.9.16

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='file:///d:/study/MLOPS/MLOps_Practice/experiment_track/mlruns/1', creation_time=1688550087908, experiment_id='1', last_update_time=1688550087908, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715212021978

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "Ahmed")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.001
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()
)
# Out:
# [12:18:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.32368
# [1]	validation-rmse:14.39902
# [2]	validation-rmse:12.21517
# [3]	validation-rmse:10.60708
# [4]	validation-rmse:9.44716
# [5]	validation-rmse:8.62002
# [6]	validation-rmse:8.03551
# [7]	validation-rmse:7.62692
# [8]	validation-rmse:7.34235
# [9]	validation-rmse:7.14305
# [10]	validation-rmse:7.00059
# [11]	validation-rmse:6.89809
# [12]	validation-rmse:6.82535
# [13]	validation-rmse:6.77326
# [14]	validation-rmse:6.73076
# [15]	validation-rmse:6.70108
# [16]	validation-rmse:6.67491
# [17]	validation-rmse:6.65537
# [18]	validation-rmse:6.63870
# [19]	validation-rmse:6.62628
# [20]	validation-rmse:6.61718
# [21]	validation-rmse:6.60910
# [22]	validation-rmse:6.60278
# [23]	validation-rmse:6.59792
# [24]	validation-rmse:6.59314
# [25]	validation-rmse:6.58975
# [26]	validation-rmse:6.58744
# [27]	validation-rmse:6.58518
# [28]	validation-rmse:6.58166
# [29]	validation-rmse:6.57960
# [30]	validation-rmse:6.57774
# [31]	validation-rmse:6.57640
# [32]	validation-rmse:6.57523
# [33]	validation-rmse:6.57391
# [34]	validation-rmse:6.57262
# [35]	validation-rmse:6.57126
# [36]	validation-rmse:6.57008
# [37]	validation-rmse:6.56942
# [38]	validation-rmse:6.56874
# [39]	validation-rmse:6.56801
# [40]	validation-rmse:6.56753
# [41]	validation-rmse:6.56708
# [42]	validation-rmse:6.56636
# [43]	validation-rmse:6.56552
# [44]	validation-rmse:6.56425
# [45]	validation-rmse:6.56334
# [46]	validation-rmse:6.56261
# [47]	validation-rmse:6.56203
# [48]	validation-rmse:6.56131
# [49]	validation-rmse:6.56070
# [50]	validation-rmse:6.55994
# [51]	validation-rmse:6.55952
# [52]	validation-rmse:6.55875
# [53]	validation-rmse:6.55856
# [54]	validation-rmse:6.55735
# [55]	validation-rmse:6.55675
# [56]	validation-rmse:6.55505
# [57]	validation-rmse:6.55459
# [58]	validation-rmse:6.55394
# [59]	validation-rmse:6.55346
# [60]	validation-rmse:6.55300
# [61]	validation-rmse:6.55293
# [62]	validation-rmse:6.55252
# [63]	validation-rmse:6.55130
# [64]	validation-rmse:6.55099
# [65]	validation-rmse:6.55004
# [66]	validation-rmse:6.54985
# [67]	validation-rmse:6.54963
# [68]	validation-rmse:6.54920
# [69]	validation-rmse:6.54870
# [70]	validation-rmse:6.54835
# [71]	validation-rmse:6.54744
# [72]	validation-rmse:6.54725
# [73]	validation-rmse:6.54621
# [74]	validation-rmse:6.54598
# [75]	validation-rmse:6.54589
# [76]	validation-rmse:6.54561
# [77]	validation-rmse:6.54549
# [78]	validation-rmse:6.54525
# [79]	validation-rmse:6.54528
# [80]	validation-rmse:6.54501
# [81]	validation-rmse:6.54446
# [82]	validation-rmse:6.54411
# [83]	validation-rmse:6.54385
# [84]	validation-rmse:6.54341
# [85]	validation-rmse:6.54325
# [86]	validation-rmse:6.54307
# [87]	validation-rmse:6.54302
# [88]	validation-rmse:6.54259
# [89]	validation-rmse:6.54192
# [90]	validation-rmse:6.54176
# [91]	validation-rmse:6.54088
# [92]	validation-rmse:6.54084
# [93]	validation-rmse:6.54050
# [94]	validation-rmse:6.53982
# [95]	validation-rmse:6.53950
# [96]	validation-rmse:6.53931
# [97]	validation-rmse:6.53935
# [98]	validation-rmse:6.53925
# [99]	validation-rmse:6.53892
# [12:18:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.44391
# [1]	validation-rmse:17.88432
# [2]	validation-rmse:16.49661
# [3]	validation-rmse:15.26397
# [4]	validation-rmse:14.17003
# [5]	validation-rmse:13.20373
# [6]	validation-rmse:12.35181
# [7]	validation-rmse:11.60260
# [8]	validation-rmse:10.94644
# [9]	validation-rmse:10.37194
# [10]	validation-rmse:9.87145
# [11]	validation-rmse:9.43656
# [12]	validation-rmse:9.05942
# [13]	validation-rmse:8.73371
# [14]	validation-rmse:8.45192
# [15]	validation-rmse:8.21003
# [16]	validation-rmse:8.00175
# [17]	validation-rmse:7.82168
# [18]	validation-rmse:7.66709
# [19]	validation-rmse:7.53425
# [20]	validation-rmse:7.41918
# [21]	validation-rmse:7.32068
# [22]	validation-rmse:7.23526
# [23]	validation-rmse:7.16220
# [24]	validation-rmse:7.09825
# [25]	validation-rmse:7.04326
# [26]	validation-rmse:6.99565
# [27]	validation-rmse:6.95406
# [28]	validation-rmse:6.91761
# [29]	validation-rmse:6.88609
# [30]	validation-rmse:6.85875
# [31]	validation-rmse:6.83471
# [32]	validation-rmse:6.81363
# [33]	validation-rmse:6.79453
# [34]	validation-rmse:6.77856
# [35]	validation-rmse:6.76363
# [36]	validation-rmse:6.75043
# [37]	validation-rmse:6.73877
# [38]	validation-rmse:6.72802
# [39]	validation-rmse:6.71886
# [40]	validation-rmse:6.71089
# [41]	validation-rmse:6.70343
# [42]	validation-rmse:6.69657
# [43]	validation-rmse:6.69045
# [44]	validation-rmse:6.68544
# [45]	validation-rmse:6.68007
# [46]	validation-rmse:6.67498
# [47]	validation-rmse:6.67093
# [48]	validation-rmse:6.66621
# [49]	validation-rmse:6.66317
# [50]	validation-rmse:6.66013
# [51]	validation-rmse:6.65766
# [52]	validation-rmse:6.65410
# [53]	validation-rmse:6.65153
# [54]	validation-rmse:6.64978
# [55]	validation-rmse:6.64781
# [56]	validation-rmse:6.64633
# [57]	validation-rmse:6.64480
# [58]	validation-rmse:6.64272
# [59]	validation-rmse:6.64156
# [60]	validation-rmse:6.64028
# [61]	validation-rmse:6.63898
# [62]	validation-rmse:6.63748
# [63]	validation-rmse:6.63643
# [64]	validation-rmse:6.63543
# [65]	validation-rmse:6.63459
# [66]	validation-rmse:6.63378
# [67]	validation-rmse:6.63279
# [68]	validation-rmse:6.63210
# [69]	validation-rmse:6.63135
# [70]	validation-rmse:6.63032
# [71]	validation-rmse:6.62947
# [72]	validation-rmse:6.62872
# [73]	validation-rmse:6.62759
# [74]	validation-rmse:6.62711
# [75]	validation-rmse:6.62651
# [76]	validation-rmse:6.62602
# [77]	validation-rmse:6.62536
# [78]	validation-rmse:6.62494
# [79]	validation-rmse:6.62418
# [80]	validation-rmse:6.62378
# [81]	validation-rmse:6.62319
# [82]	validation-rmse:6.62286
# [83]	validation-rmse:6.62229
# [84]	validation-rmse:6.62182
# [85]	validation-rmse:6.62142
# [86]	validation-rmse:6.62090
# [87]	validation-rmse:6.62043
# [88]	validation-rmse:6.61960
# [89]	validation-rmse:6.61932
# [90]	validation-rmse:6.61895
# [91]	validation-rmse:6.61866
# [92]	validation-rmse:6.61842
# [93]	validation-rmse:6.61790
# [94]	validation-rmse:6.61755
# [95]	validation-rmse:6.61702
# [96]	validation-rmse:6.61681
# [97]	validation-rmse:6.61642
# [98]	validation-rmse:6.61601
# [99]	validation-rmse:6.61559
# [12:18:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:8.03306
# [1]	validation-rmse:6.72392
# [2]	validation-rmse:6.57304
# [3]	validation-rmse:6.54188
# [4]	validation-rmse:6.53120
# [5]	validation-rmse:6.52464
# [6]	validation-rmse:6.51569
# [7]	validation-rmse:6.50587
# [8]	validation-rmse:6.50188
# [9]	validation-rmse:6.49758
# [10]	validation-rmse:6.49665
# [11]	validation-rmse:6.48931
# [12]	validation-rmse:6.48488
# [13]	validation-rmse:6.47989
# [14]	validation-rmse:6.47538
# [15]	validation-rmse:6.47244
# [16]	validation-rmse:6.46790
# [17]	validation-rmse:6.46601
# [18]	validation-rmse:6.46486
# [19]	validation-rmse:6.46517
# [20]	validation-rmse:6.46753
# [21]	validation-rmse:6.46338
# [22]	validation-rmse:6.46194
# [23]	validation-rmse:6.45980
# [24]	validation-rmse:6.46169
# [25]	validation-rmse:6.46702
# [26]	validation-rmse:6.46760
# [27]	validation-rmse:6.46755
# [28]	validation-rmse:6.46883
# [29]	validation-rmse:6.46832
# [30]	validation-rmse:6.47800
# [31]	validation-rmse:6.47914
# [32]	validation-rmse:6.47768
# [33]	validation-rmse:6.47739
# [34]	validation-rmse:6.47810
# [35]	validation-rmse:6.47768
# [36]	validation-rmse:6.48736
# [37]	validation-rmse:6.48751
# [38]	validation-rmse:6.48741
# [39]	validation-rmse:6.48644
# [40]	validation-rmse:6.48663
# [41]	validation-rmse:6.48702
# [42]	validation-rmse:6.48740
# [43]	validation-rmse:6.48668
# [44]	validation-rmse:6.48670
# [45]	validation-rmse:6.48489
# [46]	validation-rmse:6.48526
# [47]	validation-rmse:6.48842
# [48]	validation-rmse:6.49927
# [49]	validation-rmse:6.49825
# [50]	validation-rmse:6.50140
# [51]	validation-rmse:6.50232
# [52]	validation-rmse:6.50276
# [53]	validation-rmse:6.50338
# [54]	validation-rmse:6.50401
# [55]	validation-rmse:6.50771
# [56]	validation-rmse:6.50874
# [57]	validation-rmse:6.50892
# [58]	validation-rmse:6.50877
# [59]	validation-rmse:6.51031
# [60]	validation-rmse:6.51171
# [61]	validation-rmse:6.51499
# [62]	validation-rmse:6.51577
# [63]	validation-rmse:6.52204
# [64]	validation-rmse:6.52436
# [65]	validation-rmse:6.52902
# [66]	validation-rmse:6.53043
# [67]	validation-rmse:6.53520
# [68]	validation-rmse:6.53853
# [69]	validation-rmse:6.53918
# [70]	validation-rmse:6.54025
# [71]	validation-rmse:6.53938
# [72]	validation-rmse:6.54061
# [73]	validation-rmse:6.54045
# [12:18:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:13.01846
# [1]	validation-rmse:9.25735
# [2]	validation-rmse:7.69408
# [3]	validation-rmse:7.07119
# [4]	validation-rmse:6.82071
# [5]	validation-rmse:6.70005
# [6]	validation-rmse:6.64423
# [7]	validation-rmse:6.61280
# [8]	validation-rmse:6.58951
# [9]	validation-rmse:6.57762
# [10]	validation-rmse:6.57172
# [11]	validation-rmse:6.56721
# [12]	validation-rmse:6.56362
# [13]	validation-rmse:6.56069
# [14]	validation-rmse:6.55950
# [15]	validation-rmse:6.55750
# [16]	validation-rmse:6.55137
# [17]	validation-rmse:6.55097
# [18]	validation-rmse:6.54896
# [19]	validation-rmse:6.54777
# [20]	validation-rmse:6.54610
# [21]	validation-rmse:6.54342
# [22]	validation-rmse:6.54328
# [23]	validation-rmse:6.54222
# [24]	validation-rmse:6.54144
# [25]	validation-rmse:6.54148
# [26]	validation-rmse:6.54085
# [27]	validation-rmse:6.53967
# [28]	validation-rmse:6.53805
# [29]	validation-rmse:6.53746
# [30]	validation-rmse:6.53751
# [31]	validation-rmse:6.53735
# [32]	validation-rmse:6.53542
# [33]	validation-rmse:6.53471
# [34]	validation-rmse:6.53478
# [35]	validation-rmse:6.53479
# [36]	validation-rmse:6.53469
# [37]	validation-rmse:6.53475
# [38]	validation-rmse:6.53381
# [39]	validation-rmse:6.53525
# [40]	validation-rmse:6.53402
# [41]	validation-rmse:6.53363
# [42]	validation-rmse:6.53311
# [43]	validation-rmse:6.53396
# [44]	validation-rmse:6.53298
# [45]	validation-rmse:6.53515
# [46]	validation-rmse:6.53445
# [47]	validation-rmse:6.53426
# [48]	validation-rmse:6.53476
# [49]	validation-rmse:6.53461
# [50]	validation-rmse:6.53457
# [51]	validation-rmse:6.53420
# [52]	validation-rmse:6.53450
# [53]	validation-rmse:6.53406
# [54]	validation-rmse:6.53494
# [55]	validation-rmse:6.53627
# [56]	validation-rmse:6.53623
# [57]	validation-rmse:6.53571
# [58]	validation-rmse:6.53449
# [59]	validation-rmse:6.53456
# [60]	validation-rmse:6.53454
# [61]	validation-rmse:6.53447
# [62]	validation-rmse:6.53456
# [63]	validation-rmse:6.53485
# [64]	validation-rmse:6.53474
# [65]	validation-rmse:6.53486
# [66]	validation-rmse:6.53507
# [67]	validation-rmse:6.53516
# [68]	validation-rmse:6.53490
# [69]	validation-rmse:6.53512
# [70]	validation-rmse:6.53579
# [71]	validation-rmse:6.53606
# [72]	validation-rmse:6.53592
# [73]	validation-rmse:6.53556
# [74]	validation-rmse:6.53565
# [75]	validation-rmse:6.53587
# [76]	validation-rmse:6.53553
# [77]	validation-rmse:6.53536
# [78]	validation-rmse:6.53584
# [79]	validation-rmse:6.53724
# [80]	validation-rmse:6.53779
# [81]	validation-rmse:6.53736
# [82]	validation-rmse:6.53882
# [83]	validation-rmse:6.53835
# [84]	validation-rmse:6.53851
# [85]	validation-rmse:6.53906
# [86]	validation-rmse:6.53857
# [87]	validation-rmse:6.53872
# [88]	validation-rmse:6.53863
# [89]	validation-rmse:6.53849
# [90]	validation-rmse:6.53855
# [91]	validation-rmse:6.53855
# [92]	validation-rmse:6.53856
# [93]	validation-rmse:6.53844
# [12:18:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:16.45434
# [1]	validation-rmse:13.13593
# [2]	validation-rmse:10.86128
# [3]	validation-rmse:9.34005
# [4]	validation-rmse:8.34710
# [5]	validation-rmse:7.71418
# [6]	validation-rmse:7.30790
# [7]	validation-rmse:7.04985
# [8]	validation-rmse:6.87780
# [9]	validation-rmse:6.76708
# [10]	validation-rmse:6.68947
# [11]	validation-rmse:6.63807
# [12]	validation-rmse:6.59885
# [13]	validation-rmse:6.57027
# [14]	validation-rmse:6.54933
# [15]	validation-rmse:6.53311
# [16]	validation-rmse:6.52186
# [17]	validation-rmse:6.51371
# [18]	validation-rmse:6.50716
# [19]	validation-rmse:6.50231
# [20]	validation-rmse:6.49743
# [21]	validation-rmse:6.49430
# [22]	validation-rmse:6.48992
# [23]	validation-rmse:6.48679
# [24]	validation-rmse:6.48387
# [25]	validation-rmse:6.48156
# [26]	validation-rmse:6.47857
# [27]	validation-rmse:6.47775
# [28]	validation-rmse:6.47604
# [29]	validation-rmse:6.47475
# [30]	validation-rmse:6.47336
# [31]	validation-rmse:6.47065
# [32]	validation-rmse:6.46826
# [33]	validation-rmse:6.46728
# [34]	validation-rmse:6.46595
# [35]	validation-rmse:6.46471
# [36]	validation-rmse:6.46335
# [37]	validation-rmse:6.46135
# [38]	validation-rmse:6.46009
# [39]	validation-rmse:6.45940
# [40]	validation-rmse:6.45716
# [41]	validation-rmse:6.45576
# [42]	validation-rmse:6.45425
# [43]	validation-rmse:6.45379
# [44]	validation-rmse:6.45261
# [45]	validation-rmse:6.45108
# [46]	validation-rmse:6.45002
# [47]	validation-rmse:6.44855
# [48]	validation-rmse:6.44811
# [49]	validation-rmse:6.44731
# [50]	validation-rmse:6.44672
# [51]	validation-rmse:6.44640
# [52]	validation-rmse:6.44570
# [53]	validation-rmse:6.44524
# [54]	validation-rmse:6.44402
# [55]	validation-rmse:6.44337
# [56]	validation-rmse:6.44205
# [57]	validation-rmse:6.44183
# [58]	validation-rmse:6.44094
# [59]	validation-rmse:6.44015
# [60]	validation-rmse:6.43886
# [61]	validation-rmse:6.43749
# [62]	validation-rmse:6.43741
# [63]	validation-rmse:6.43698
# [64]	validation-rmse:6.43691
# [65]	validation-rmse:6.43610
# [66]	validation-rmse:6.43524
# [67]	validation-rmse:6.43545
# [68]	validation-rmse:6.43462
# [69]	validation-rmse:6.43423
# [70]	validation-rmse:6.43274
# [71]	validation-rmse:6.43227
# [72]	validation-rmse:6.43121
# [73]	validation-rmse:6.43066
# [74]	validation-rmse:6.43027
# [75]	validation-rmse:6.42952
# [76]	validation-rmse:6.42928
# [77]	validation-rmse:6.42815
# [78]	validation-rmse:6.42777
# [79]	validation-rmse:6.42766
# [80]	validation-rmse:6.42739
# [81]	validation-rmse:6.42681
# [82]	validation-rmse:6.42619
# [83]	validation-rmse:6.42588
# [84]	validation-rmse:6.42563
# [85]	validation-rmse:6.42510
# [86]	validation-rmse:6.42469
# [87]	validation-rmse:6.42496
# [88]	validation-rmse:6.42436
# [89]	validation-rmse:6.42423
# [90]	validation-rmse:6.42411
# [91]	validation-rmse:6.42308
# [92]	validation-rmse:6.42280
# [93]	validation-rmse:6.42255
# [94]	validation-rmse:6.42208
# [95]	validation-rmse:6.42211
# [96]	validation-rmse:6.42174
# [97]	validation-rmse:6.42214
# [98]	validation-rmse:6.42160
# [99]	validation-rmse:6.42103
# [12:19:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:9.35074
# [1]	validation-rmse:7.14871
# [2]	validation-rmse:6.76809
# [3]	validation-rmse:6.69671
# [4]	validation-rmse:6.67287
# [5]	validation-rmse:6.65600
# [6]	validation-rmse:6.65043
# [7]	validation-rmse:6.64252
# [8]	validation-rmse:6.63752
# [9]	validation-rmse:6.63245
# [10]	validation-rmse:6.62838
# [11]	validation-rmse:6.62549
# [12]	validation-rmse:6.62048
# [13]	validation-rmse:6.61464
# [14]	validation-rmse:6.61025
# [15]	validation-rmse:6.60694
# [16]	validation-rmse:6.59995
# [17]	validation-rmse:6.59509
# [18]	validation-rmse:6.59149
# [19]	validation-rmse:6.58973
# [20]	validation-rmse:6.58372
# [21]	validation-rmse:6.57799
# [22]	validation-rmse:6.57383
# [23]	validation-rmse:6.57267
# [24]	validation-rmse:6.57153
# [25]	validation-rmse:6.56858
# [26]	validation-rmse:6.56633
# [27]	validation-rmse:6.56481
# [28]	validation-rmse:6.56166
# [29]	validation-rmse:6.55890
# [30]	validation-rmse:6.55488
# [31]	validation-rmse:6.55293
# [32]	validation-rmse:6.54305
# [33]	validation-rmse:6.54070
# [34]	validation-rmse:6.53979
# [35]	validation-rmse:6.53770
# [36]	validation-rmse:6.53490
# [37]	validation-rmse:6.53354
# [38]	validation-rmse:6.53055
# [39]	validation-rmse:6.52921
# [40]	validation-rmse:6.52712
# [41]	validation-rmse:6.52508
# [42]	validation-rmse:6.52341
# [43]	validation-rmse:6.52176
# [44]	validation-rmse:6.51898
# [45]	validation-rmse:6.51792
# [46]	validation-rmse:6.51411
# [47]	validation-rmse:6.51093
# [48]	validation-rmse:6.50775
# [49]	validation-rmse:6.50321
# [50]	validation-rmse:6.49959
# [51]	validation-rmse:6.49752
# [52]	validation-rmse:6.49682
# [53]	validation-rmse:6.49523
# [54]	validation-rmse:6.49449
# [55]	validation-rmse:6.49399
# [56]	validation-rmse:6.49289
# [57]	validation-rmse:6.48995
# [58]	validation-rmse:6.48530
# [59]	validation-rmse:6.48354
# [60]	validation-rmse:6.48099
# [61]	validation-rmse:6.47921
# [62]	validation-rmse:6.47885
# [63]	validation-rmse:6.47745
# [64]	validation-rmse:6.47663
# [65]	validation-rmse:6.47528
# [66]	validation-rmse:6.47172
# [67]	validation-rmse:6.47096
# [68]	validation-rmse:6.46977
# [69]	validation-rmse:6.46881
# [70]	validation-rmse:6.46829
# [71]	validation-rmse:6.46790
# [72]	validation-rmse:6.46620
# [73]	validation-rmse:6.46433
# [74]	validation-rmse:6.46225
# [75]	validation-rmse:6.46020
# [76]	validation-rmse:6.45934
# [77]	validation-rmse:6.45700
# [78]	validation-rmse:6.45646
# [79]	validation-rmse:6.45523
# [80]	validation-rmse:6.45368
# [81]	validation-rmse:6.45166
# [82]	validation-rmse:6.44860
# [83]	validation-rmse:6.44585
# [84]	validation-rmse:6.44509
# [85]	validation-rmse:6.44401
# [86]	validation-rmse:6.44217
# [87]	validation-rmse:6.44031
# [88]	validation-rmse:6.43860
# [89]	validation-rmse:6.43748
# [90]	validation-rmse:6.43605
# [91]	validation-rmse:6.43411
# [92]	validation-rmse:6.43323
# [93]	validation-rmse:6.43194
# [94]	validation-rmse:6.43062
# [95]	validation-rmse:6.42957
# [96]	validation-rmse:6.42877
# [97]	validation-rmse:6.42843
# [98]	validation-rmse:6.42788
# [99]	validation-rmse:6.42633
# [12:19:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.05103
# [1]	validation-rmse:17.19380
# [2]	validation-rmse:15.58802
# [3]	validation-rmse:14.20594
# [4]	validation-rmse:13.01929
# [5]	validation-rmse:12.00516
# [6]	validation-rmse:11.14022
# [7]	validation-rmse:10.40674
# [8]	validation-rmse:9.78949
# [9]	validation-rmse:9.27238
# [10]	validation-rmse:8.83830
# [11]	validation-rmse:8.47617
# [12]	validation-rmse:8.17572
# [13]	validation-rmse:7.92644
# [14]	validation-rmse:7.71845
# [15]	validation-rmse:7.54600
# [16]	validation-rmse:7.40248
# [17]	validation-rmse:7.28323
# [18]	validation-rmse:7.18234
# [19]	validation-rmse:7.09965
# [20]	validation-rmse:7.02976
# [21]	validation-rmse:6.97164
# [22]	validation-rmse:6.92284
# [23]	validation-rmse:6.88116
# [24]	validation-rmse:6.84633
# [25]	validation-rmse:6.81640
# [26]	validation-rmse:6.79114
# [27]	validation-rmse:6.76959
# [28]	validation-rmse:6.75037
# [29]	validation-rmse:6.73422
# [30]	validation-rmse:6.72016
# [31]	validation-rmse:6.70693
# [32]	validation-rmse:6.69501
# [33]	validation-rmse:6.68496
# [34]	validation-rmse:6.67620
# [35]	validation-rmse:6.66839
# [36]	validation-rmse:6.66183
# [37]	validation-rmse:6.65506
# [38]	validation-rmse:6.64945
# [39]	validation-rmse:6.64459
# [40]	validation-rmse:6.64039
# [41]	validation-rmse:6.63653
# [42]	validation-rmse:6.63334
# ...
# [4]	validation-rmse:6.67370
# [5]	validation-rmse:6.58154
# [6]	validation-rmse:6.53597
# [7]	validation-rmse:6.51287
# [8]	validation-rmse:6.50297
# [9]	validation-rmse:6.49499
# [10]	validation-rmse:6.48785
# [11]	validation-rmse:6.48263
# [12]	validation-rmse:6.47665
# [13]	validation-rmse:6.47373
# [14]	validation-rmse:6.47125
# [15]	validation-rmse:6.46647
# [16]	validation-rmse:6.46334
# [17]	validation-rmse:6.46037
# [18]	validation-rmse:6.45737
# [19]	validation-rmse:6.45585
# [20]	validation-rmse:6.45523
# [21]	validation-rmse:6.45370
# [22]	validation-rmse:6.45212
# [23]	validation-rmse:6.45004
# [24]	validation-rmse:6.44880
# [25]	validation-rmse:6.44550
# [26]	validation-rmse:6.44441
# [27]	validation-rmse:6.44205
# [28]	validation-rmse:6.44081
# [29]	validation-rmse:6.43935
# [30]	validation-rmse:6.43703
# [31]	validation-rmse:6.43415
# [32]	validation-rmse:6.43226
# [33]	validation-rmse:6.43043
# [34]	validation-rmse:6.42920
# [35]	validation-rmse:6.42810
# [36]	validation-rmse:6.42751
# [37]	validation-rmse:6.42533
# [38]	validation-rmse:6.42511
# [39]	validation-rmse:6.42305
# [40]	validation-rmse:6.42274
# [41]	validation-rmse:6.42161
# [42]	validation-rmse:6.42084
# [43]	validation-rmse:6.41966
# [44]	validation-rmse:6.41970
# [45]	validation-rmse:6.41868
# [46]	validation-rmse:6.41798
# [47]	validation-rmse:6.41783
# [48]	validation-rmse:6.41852
# [49]	validation-rmse:6.41691
# [50]	validation-rmse:6.41526
# [51]	validation-rmse:6.41640
# [52]	validation-rmse:6.41569
# [53]	validation-rmse:6.41510
# [54]	validation-rmse:6.41998
# [55]	validation-rmse:6.41902
# [56]	validation-rmse:6.41933
# [57]	validation-rmse:6.42017
# [58]	validation-rmse:6.42075
# [59]	validation-rmse:6.41957
# [60]	validation-rmse:6.41938
# [61]	validation-rmse:6.41955
# [62]	validation-rmse:6.41968
# [63]	validation-rmse:6.41879
# [64]	validation-rmse:6.41949
# [65]	validation-rmse:6.41935
# [66]	validation-rmse:6.42012
# [67]	validation-rmse:6.42002
# [68]	validation-rmse:6.42034
# [69]	validation-rmse:6.42086
# [70]	validation-rmse:6.41983
# [71]	validation-rmse:6.41945
# [72]	validation-rmse:6.41989
# [73]	validation-rmse:6.41980
# [74]	validation-rmse:6.41946
# [75]	validation-rmse:6.42037
# [76]	validation-rmse:6.42109
# [77]	validation-rmse:6.41969
# [78]	validation-rmse:6.41926
# [79]	validation-rmse:6.41806
# [80]	validation-rmse:6.41758
# [81]	validation-rmse:6.41788
# [82]	validation-rmse:6.42081
# [83]	validation-rmse:6.42274
# [84]	validation-rmse:6.42246
# [85]	validation-rmse:6.42222
# [86]	validation-rmse:6.42035
# [87]	validation-rmse:6.42138
# [88]	validation-rmse:6.42145
# [89]	validation-rmse:6.42266
# [90]	validation-rmse:6.42464
# [91]	validation-rmse:6.42527
# [92]	validation-rmse:6.42498
# [93]	validation-rmse:6.42496
# [94]	validation-rmse:6.42445
# [95]	validation-rmse:6.42579
# [96]	validation-rmse:6.42624
# [97]	validation-rmse:6.42622
# [98]	validation-rmse:6.42670
# [99]	validation-rmse:6.42749
# [12:20:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:6.93778
# [1]	validation-rmse:6.76947
# [2]	validation-rmse:6.75489
# [3]	validation-rmse:6.74713
# [4]	validation-rmse:6.73558
# [5]	validation-rmse:6.73159
# [6]	validation-rmse:6.73123
# [7]	validation-rmse:6.72309
# [8]	validation-rmse:6.71710
# [9]	validation-rmse:6.72047
# [10]	validation-rmse:6.71422
# [11]	validation-rmse:6.71033
# [12]	validation-rmse:6.70526
# [13]	validation-rmse:6.70309
# [14]	validation-rmse:6.70194
# [15]	validation-rmse:6.70097
# [16]	validation-rmse:6.69646
# [17]	validation-rmse:6.69197
# [18]	validation-rmse:6.68792
# [19]	validation-rmse:6.68532
# [20]	validation-rmse:6.68101
# [21]	validation-rmse:6.68082
# [22]	validation-rmse:6.68194
# [23]	validation-rmse:6.68095
# [24]	validation-rmse:6.67966
# [25]	validation-rmse:6.67642
# [26]	validation-rmse:6.67707
# [27]	validation-rmse:6.67475
# [28]	validation-rmse:6.67314
# [29]	validation-rmse:6.67244
# [30]	validation-rmse:6.66901
# [31]	validation-rmse:6.66746
# [32]	validation-rmse:6.66861
# [33]	validation-rmse:6.66594
# [34]	validation-rmse:6.66237
# [35]	validation-rmse:6.66017
# [36]	validation-rmse:6.65962
# [37]	validation-rmse:6.65817
# [38]	validation-rmse:6.65794
# [39]	validation-rmse:6.65312
# [40]	validation-rmse:6.64944
# [41]	validation-rmse:6.64942
# [42]	validation-rmse:6.64772
# [43]	validation-rmse:6.64281
# [44]	validation-rmse:6.64358
# [45]	validation-rmse:6.64366
# [46]	validation-rmse:6.64094
# [47]	validation-rmse:6.63935
# [48]	validation-rmse:6.63889
# [49]	validation-rmse:6.63876
# [50]	validation-rmse:6.63501
# [51]	validation-rmse:6.63197
# [52]	validation-rmse:6.62833
# [53]	validation-rmse:6.62751
# [54]	validation-rmse:6.62723
# [55]	validation-rmse:6.62756
# [56]	validation-rmse:6.62615
# [57]	validation-rmse:6.62551
# [58]	validation-rmse:6.62430
# [59]	validation-rmse:6.62365
# [60]	validation-rmse:6.62310
# [61]	validation-rmse:6.61750
# [62]	validation-rmse:6.61748
# [63]	validation-rmse:6.61555
# [64]	validation-rmse:6.61546
# [65]	validation-rmse:6.61494
# [66]	validation-rmse:6.61445
# [67]	validation-rmse:6.61484
# [68]	validation-rmse:6.61568
# [69]	validation-rmse:6.61487
# [70]	validation-rmse:6.61590
# [71]	validation-rmse:6.61599
# [72]	validation-rmse:6.61418
# [73]	validation-rmse:6.62042
# [74]	validation-rmse:6.62041
# [75]	validation-rmse:6.62115
# [76]	validation-rmse:6.61836
# [77]	validation-rmse:6.61715
# [78]	validation-rmse:6.61539
# [79]	validation-rmse:6.61510
# [80]	validation-rmse:6.61530
# [81]	validation-rmse:6.61440
# [82]	validation-rmse:6.61477
# [83]	validation-rmse:6.61383
# [84]	validation-rmse:6.61371
# [85]	validation-rmse:6.61327
# [86]	validation-rmse:6.61180
# [87]	validation-rmse:6.61065
# [88]	validation-rmse:6.60927
# [89]	validation-rmse:6.60926
# [90]	validation-rmse:6.60895
# [91]	validation-rmse:6.60823
# [92]	validation-rmse:6.60830
# [93]	validation-rmse:6.60745
# [94]	validation-rmse:6.60624
# [95]	validation-rmse:6.60527
# [96]	validation-rmse:6.60524
# [97]	validation-rmse:6.60507
# [98]	validation-rmse:6.60534
# [99]	validation-rmse:6.60375
# 100%|██████████| 10/10 [02:04<00:00, 12.45s/trial, best loss: 6.421032711943238]

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=100,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [12:21:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95635
# [2]	validation-rmse:16.59103
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29029
# [5]	validation-rmse:13.32807
# [6]	validation-rmse:12.47571
# [7]	validation-rmse:11.72138
# [8]	validation-rmse:11.05825
# [9]	validation-rmse:10.47535
# [10]	validation-rmse:9.96449
# [11]	validation-rmse:9.51756
# [12]	validation-rmse:9.12641
# [13]	validation-rmse:8.78569
# [14]	validation-rmse:8.49089
# [15]	validation-rmse:8.23445
# [16]	validation-rmse:8.01207
# [17]	validation-rmse:7.81886
# [18]	validation-rmse:7.65169
# [19]	validation-rmse:7.50672
# [20]	validation-rmse:7.38153
# [21]	validation-rmse:7.27299
# [22]	validation-rmse:7.17863
# [23]	validation-rmse:7.09718
# [24]	validation-rmse:7.02603
# [25]	validation-rmse:6.96344
# [26]	validation-rmse:6.90935
# [27]	validation-rmse:6.86285
# [28]	validation-rmse:6.82157
# [29]	validation-rmse:6.78486
# [30]	validation-rmse:6.75283
# [31]	validation-rmse:6.72433
# [32]	validation-rmse:6.69838
# [33]	validation-rmse:6.67599
# [34]	validation-rmse:6.65632
# [35]	validation-rmse:6.63968
# [36]	validation-rmse:6.62456
# [37]	validation-rmse:6.61030
# [38]	validation-rmse:6.59833
# [39]	validation-rmse:6.58671
# [40]	validation-rmse:6.57678
# [41]	validation-rmse:6.56792
# [42]	validation-rmse:6.56024
# [43]	validation-rmse:6.55307
# [44]	validation-rmse:6.54644
# [45]	validation-rmse:6.54087
# [46]	validation-rmse:6.53587
# [47]	validation-rmse:6.53128
# [48]	validation-rmse:6.52719
# [49]	validation-rmse:6.52427
# [50]	validation-rmse:6.52098
# [51]	validation-rmse:6.51875
# [52]	validation-rmse:6.51547
# [53]	validation-rmse:6.51333
# [54]	validation-rmse:6.51034
# [55]	validation-rmse:6.50826
# [56]	validation-rmse:6.50668
# [57]	validation-rmse:6.50477
# [58]	validation-rmse:6.50288
# [59]	validation-rmse:6.50114
# [60]	validation-rmse:6.49931
# [61]	validation-rmse:6.49758
# [62]	validation-rmse:6.49577
# [63]	validation-rmse:6.49364
# [64]	validation-rmse:6.49179
# [65]	validation-rmse:6.49031
# [66]	validation-rmse:6.48955
# [67]	validation-rmse:6.48814
# [68]	validation-rmse:6.48684
# [69]	validation-rmse:6.48526
# [70]	validation-rmse:6.48384
# [71]	validation-rmse:6.48249
# [72]	validation-rmse:6.48180
# [73]	validation-rmse:6.48127
# [74]	validation-rmse:6.48053
# [75]	validation-rmse:6.47965
# [76]	validation-rmse:6.47878
# [77]	validation-rmse:6.47808
# [78]	validation-rmse:6.47695
# [79]	validation-rmse:6.47605
# [80]	validation-rmse:6.47528
# [81]	validation-rmse:6.47416
# [82]	validation-rmse:6.47331
# [83]	validation-rmse:6.47237
# [84]	validation-rmse:6.47146
# [85]	validation-rmse:6.47022
# [86]	validation-rmse:6.46934
# [87]	validation-rmse:6.46830
# [88]	validation-rmse:6.46799
# [89]	validation-rmse:6.46740
# [90]	validation-rmse:6.46645
# [91]	validation-rmse:6.46556
# [92]	validation-rmse:6.46451
# [93]	validation-rmse:6.46355
# [94]	validation-rmse:6.46222
# [95]	validation-rmse:6.46134
# [96]	validation-rmse:6.46099
# [97]	validation-rmse:6.46062
# [98]	validation-rmse:6.46009
# [99]	validation-rmse:6.45985

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.paquet")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# 2023/07/10 12:28:02 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2023/07/10 12:28:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\Users\Ahmed_Fayed\AppData\Roaming\Python\Python39\site-packages\_distutils_hack\__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/10 12:28:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\Users\Ahmed_Fayed\AppData\Roaming\Python\Python39\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils."
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 4
#       1 from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
#       2 from sklearn.svm import LinearSVR
# ----> 4 mlflow.sklearn.autolog()
#       6 for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):
#       8     with mlflow.start_run():
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\mlflow\utils\autologging_utils\__init__.py:414, in autologging_integration.<locals>.wrapper.<locals>.autolog(*args, **kwargs)
#     395 with set_mlflow_events_and_warnings_behavior_globally(
#     396     # MLflow warnings emitted during autologging setup / enablement are likely
#     397     # actionable and relevant to the user, so they should be emitted as normal
#    (...)
#     410     disable_warnings=is_silent_mode,
#     411 ):
#     412     _check_and_log_warning_for_unsupported_package_versions(name)
# --> 414     return _autolog(*args, **kwargs)
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\mlflow\sklearn\__init__.py:1239, in autolog(log_input_examples, log_model_signatures, log_models, log_datasets, disable, exclusive, disable_for_unsupported_versions, silent, max_tuning_runs, log_post_training_metrics, serialization_format, registered_model_name, pos_label)
#     956 @autologging_integration(FLAVOR_NAME)
#     957 def autolog(
#     958     log_input_examples=False,
#    (...)
#     970     pos_label=None,
#     971 ):  # pylint: disable=unused-argument
#     972     """
#     973     Enables (or disables) and configures autologging for scikit-learn estimators.
#     974
#    (...)
#    1237                       be logged. If used for regression model, the parameter will be ignored.
#    1238     """
# -> 1239     _autolog(
#    1240         flavor_name=FLAVOR_NAME,
#    1241         log_input_examples=log_input_examples,
#    1242         log_model_signatures=log_model_signatures,
#    1243         log_models=log_models,
#    1244         log_datasets=log_datasets,
#    1245         disable=disable,
#    1246         exclusive=exclusive,
#    1247         disable_for_unsupported_versions=disable_for_unsupported_versions,
#    1248         silent=silent,
#    1249         max_tuning_runs=max_tuning_runs,
#    1250         log_post_training_metrics=log_post_training_metrics,
#    1251         serialization_format=serialization_format,
#    1252         pos_label=pos_label,
#    1253     )
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\mlflow\sklearn\__init__.py:1799, in _autolog(flavor_name, log_input_examples, log_model_signatures, log_models, log_datasets, disable, exclusive, disable_for_unsupported_versions, silent, max_tuning_runs, log_post_training_metrics, serialization_format, pos_label)
#    1797     allow_children_patch = True
#    1798 else:
# -> 1799     estimators_to_patch = _gen_estimators_to_patch()
#    1800     patched_fit_impl = fit_mlflow
#    1801     allow_children_patch = False
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\mlflow\sklearn\__init__.py:97, in _gen_estimators_to_patch()
#      91 def _gen_estimators_to_patch():
#      92     from mlflow.sklearn.utils import (
#      93         _all_estimators,
#      94         _get_meta_estimators_for_autologging,
#      95     )
# ---> 97     _, estimators_to_patch = zip(*_all_estimators())
#      98     # Ensure that relevant meta estimators (e.g. GridSearchCV, Pipeline) are selected
#      99     # for patching if they are not already included in the output of `all_estimators()`
#     100     estimators_to_patch = set(estimators_to_patch).union(
#     101         set(_get_meta_estimators_for_autologging())
#     102     )
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\mlflow\sklearn\utils.py:856, in _all_estimators()
#     853 try:
#     854     from sklearn.utils import all_estimators
# --> 856     return all_estimators()
#     857 except ImportError:
#     858     return _backported_all_estimators()
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\sklearn\utils\discovery.py:63, in all_estimators(type_filter)
#      60 # Ignore deprecation warnings triggered at import time and from walking
#      61 # packages
#      62 with ignore_warnings(category=FutureWarning):
# ---> 63     for _, module_name, _ in pkgutil.walk_packages(path=[root], prefix="sklearn."):
#      64         module_parts = module_name.split(".")
#      65         if (
#      66             any(part in _MODULE_TO_IGNORE for part in module_parts)
#      67             or "._" in module_name
#      68         ):
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\pkgutil.py:93, in walk_packages(path, prefix, onerror)
#      91 if info.ispkg:
#      92     try:
# ---> 93         __import__(info.name)
#      94     except ImportError:
#      95         if onerror is not None:
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\sklearn\_build_utils\__init__.py:15
#      13 from .._min_dependencies import CYTHON_MIN_VERSION
#      14 from ..externals._packaging.version import parse
# ---> 15 from .openmp_helpers import check_openmp_support
#      16 from .pre_build_helpers import basic_check_build
#      18 DEFAULT_ROOT = "sklearn"
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\sklearn\_build_utils\openmp_helpers.py:12
#       9 import textwrap
#      10 import warnings
# ---> 12 from .pre_build_helpers import compile_test_program
#      15 def get_openmp_flag():
#      16     if sys.platform == "win32":
#
# File c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\site-packages\sklearn\_build_utils\pre_build_helpers.py:10
#       7 import tempfile
#       8 import textwrap
# ---> 10 from setuptools.command.build_ext import customize_compiler, new_compiler
#      13 def compile_test_program(code, extra_preargs=None, extra_postargs=None):
#      14     """Check that some C code can be compiled and run"""
#
# File ~\AppData\Roaming\Python\Python39\site-packages\setuptools\__init__.py:7
#       4 import os
#       5 import re
# ----> 7 import _distutils_hack.override  # noqa: F401
#       9 import distutils.core
#      10 from distutils.errors import DistutilsOptionError
#
# File ~\AppData\Roaming\Python\Python39\site-packages\_distutils_hack\override.py:1
# ----> 1 __import__('_distutils_hack').do_override()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\_distutils_hack\__init__.py:77, in do_override()
#      75 if enabled():
#      76     warn_distutils_present()
# ---> 77     ensure_local_distutils()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\_distutils_hack\__init__.py:64, in ensure_local_distutils()
#      62 # check that submodules load as expected
#      63 core = importlib.import_module('distutils.core')
# ---> 64 assert '_distutils' in core.__file__, core.__file__
#      65 assert 'setuptools._distutils.log' not in sys.modules
#
# AssertionError: c:\Users\Ahmed_Fayed\anaconda3\envs\exp-tracking-env\lib\distutils\core.py
